# %% [markdown]
# # Testing TD API

# %%
import requests

client_id = 'KOOWEZGOW4WT4S5RFRGCOOLGLZCUCPOA'

# %% [markdown]
# This displays the basic ways to make a call to the api.
#
# This is not an 'authenticated' request which means I have not provided an access token that would be necessary for the program to be able to trade.
#
# # Below is an example of how to make a request for price history
#
# ## Notes:
# 1) This makes use of the requests library to make calls to the url.
#
# 2) The endpoint below is the generic url for price history calls.
#
# 3) The request will return a dict of length, which includes, first the ***candles***, second the symbol requested and last a boolean that tells you if it ***candles*** is empty.
#
# ## Potential Parameters
# 1) Api key is straightforward and can be gotten from the api dashboard.
#
# 2) The type of period to show. Valid values are day, month, year, or ytd (year to date). Default is day.
#
# 3) The number of periods to show. Valid periods by periodType (defaults marked with an asterisk):
#     day: 1, 2, 3, 4, 5, 10*
#     month: 1*, 2, 3, 6
#     year: 1*, 2, 3, 5, 10, 15, 20
#     ytd: 1*
#
# 4) The type of frequency with which a new candle is formed. Valid frequencyTypes by periodType (defaults marked with an asterisk):
#     day: minute*
#     month: daily, weekly*
#     year: daily, weekly, monthly*
#     ytd: daily, weekly*
#
# 5) The number of the frequencyType to be included in each candle. Valid frequencies by frequencyType (defaults marked with an asterisk):
#     minute: 1*, 5, 10, 15, 30
#     daily: 1*
#     weekly: 1*
#     monthly: 1*
#
# 6) End date as ***milliseconds since epoch.*** If startDate and endDate are provided, period should not be provided. Default is previous trading day.
#
# 7) Start date as ***milliseconds since epoch.*** If startDate and endDate are provided, period should not be provided.
#
# 8) Is a boolean for extended hours.

# %%
# Define our endpoint
endpoint = r"https://api.tdameritrade.com/v1/marketdata/{}/pricehistory".format('AMZN')

# Define our payload
payload = {'apikey':client_id,
           'periodType':'ytd',
           'frequencyType':'daily',
           'frequency':'1',
           'endDate':'1585790672000',
           'startDate':'1577836800000',
           'needExtendedHoursData':'true'}

# Make a request
content = requests.get(url = endpoint, params = payload)

data = content.json()
data
# Out:
# {'candles': [{'open': 1842.0,
#    'high': 1853.26,
#    'low': 1832.23,
#    'close': 1847.84,
#    'volume': 2510380,
#    'datetime': 1577772000000},
#   {'open': 1875.0,
#    'high': 1898.01,
#    'low': 1864.15,
#    'close': 1898.01,
#    'volume': 4035910,
#    'datetime': 1577944800000},
#   {'open': 1864.5,
#    'high': 1886.1965,
#    'low': 1864.5,
#    'close': 1874.97,
#    'volume': 3766604,
#    'datetime': 1578031200000},
#   {'open': 1860.0,
#    'high': 1903.69,
#    'low': 1860.0,
#    'close': 1902.88,
#    'volume': 4065698,
#    'datetime': 1578290400000},
#   {'open': 1904.5,
#    'high': 1913.89,
#    'low': 1892.0433,
#    'close': 1906.86,
#    'volume': 4134010,
#    'datetime': 1578376800000},
#   {'open': 1898.04,
#    'high': 1910.9999,
#    'low': 1886.4448,
#    'close': 1891.97,
#    'volume': 3511966,
#    'datetime': 1578463200000},
#   {'open': 1909.89,
#    'high': 1917.82,
#    'low': 1895.8038,
#    'close': 1901.05,
#    'volume': 3174962,
#    'datetime': 1578549600000},
#   {'open': 1905.37,
#    'high': 1906.94,
#    'low': 1880.0,
#    'close': 1883.16,
#    'volume': 2856959,
#    'datetime': 1578636000000},
#   {'open': 1891.31,
#    'high': 1898.0,
#    'low': 1880.8,
#    'close': 1891.3,
#    'volume': 2785844,
#    'datetime': 1578895200000},
#   {'open': 1885.88,
#    'high': 1887.11,
#    'low': 1858.55,
#    'close': 1869.44,
#    'volume': 3446381,
#    'datetime': 1578981600000},
#   {'open': 1872.25,
#    'high': 1878.86,
#    'low': 1855.09,
#    'close': 1862.02,
#    'volume': 2896592,
#    'datetime': 1579068000000},
#   {'open': 1882.99,
#    'high': 1885.59,
#    'low': 1866.02,
#    'close': 1877.94,
#    'volume': 2659493,
#    'datetime': 1579154400000},
#   {'open': 1885.89,
#    'high': 1886.64,
#    'low': 1857.25,
#    'close': 1864.72,
#    'volume': 3997340,
#    'datetime': 1579240800000},
#   {'open': 1865.0,
#    'high': 1894.27,
#    'low': 1860.0,
#    'close': 1892.0,
#    'volume': 3707785,
#    'datetime': 1579586400000},
#   {'open': 1896.09,
#    'high': 1902.5,
#    'low': 1883.34,
#    'close': 1887.46,
#    'volume': 3216257,
#    'datetime': 1579672800000},
#   {'open': 1885.11,
#    'high': 1889.975,
#    'low': 1872.76,
#    'close': 1884.58,
#    'volume': 2484613,
#    'datetime': 1579759200000},
#   {'open': 1891.37,
#    'high': 1894.99,
#    'low': 1847.44,
#    'close': 1861.64,
#    'volume': 3766181,
#    'datetime': 1579845600000},
#   {'open': 1820.0,
#    'high': 1841.0,
#    'low': 1815.34,
#    'close': 1828.34,
#    'volume': 3528509,
#    'datetime': 1580104800000},
#   {'open': 1840.5,
#    'high': 1858.11,
#    'low': 1830.02,
#    'close': 1853.25,
#    'volume': 2808040,
#    'datetime': 1580191200000},
#   {'open': 1864.0,
#    'high': 1874.75,
#    'low': 1855.02,
#    'close': 1858.0,
#    'volume': 2101390,
#    'datetime': 1580277600000},
#   {'open': 1858.0,
#    'high': 1872.87,
#    'low': 1850.61,
#    'close': 1870.68,
#    'volume': 6327438,
#    'datetime': 1580364000000},
#   {'open': 2051.47,
#    'high': 2055.72,
#    'low': 2002.27,
#    'close': 2008.72,
#    'volume': 15567283,
#    'datetime': 1580450400000},
#   {'open': 2010.6,
#    'high': 2048.5,
#    'low': 2000.25,
#    'close': 2004.2,
#    'volume': 5899094,
#    'datetime': 1580709600000},
#   {'open': 2029.88,
#    'high': 2059.8,
#    'low': 2015.37,
#    'close': 2049.67,
#    'volume': 5289338,
#    'datetime': 1580796000000},
#   {'open': 2071.02,
#    'high': 2071.02,
#    'low': 2032.0,
#    'close': 2039.87,
#    'volume': 4376174,
#    'datetime': 1580882400000},
#   {'open': 2041.02,
#    'high': 2056.3,
#    'low': 2024.8001,
#    'close': 2050.23,
#    'volume': 3182954,
#    'datetime': 1580968800000},
#   {'open': 2041.99,
#    'high': 2098.53,
#    'low': 2038.1,
#    'close': 2079.28,
#    'volume': 5095347,
#    'datetime': 1581055200000},
#   {'open': 2085.01,
#    'high': 2135.6,
#    'low': 2084.96,
#    'close': 2133.91,
#    'volume': 5056235,
#    'datetime': 1581314400000},
#   {'open': 2150.9,
#    'high': 2185.95,
#    'low': 2136.0,
#    'close': 2150.8,
#    'volume': 5746011,
#    'datetime': 1581400800000},
#   {'open': 2163.2,
#    'high': 2180.2494,
#    'low': 2155.29,
#    'close': 2160.0,
#    'volume': 3334264,
#    'datetime': 1581487200000},
#   {'open': 2144.99,
#    'high': 2170.28,
#    'low': 2142.0,
#    'close': 2149.87,
#    'volume': 3031791,
#    'datetime': 1581573600000},
#   {'open': 2155.68,
#    'high': 2159.0352,
#    'low': 2125.89,
#    'close': 2134.87,
#    'volume': 2606169,
#    'datetime': 1581660000000},
#   {'open': 2125.02,
#    'high': 2166.07,
#    'low': 2124.105,
#    'close': 2155.67,
#    'volume': 2951070,
#    'datetime': 1582005600000},
#   {'open': 2167.8,
#    'high': 2185.1,
#    'low': 2161.12,
#    'close': 2170.22,
#    'volume': 2561165,
#    'datetime': 1582092000000},
#   {'open': 2173.07,
#    'high': 2176.79,
#    'low': 2127.45,
#    'close': 2153.1,
#    'volume': 3131342,
#    'datetime': 1582178400000},
#   {'open': 2142.15,
#    'high': 2144.55,
#    'low': 2088.0,
#    'close': 2095.97,
#    'volume': 4650740,
#    'datetime': 1582264800000},
#   {'open': 2003.18,
#    'high': 2039.295,
#    'low': 1987.9742,
#    'close': 2009.29,
#    'volume': 6546997,
#    'datetime': 1582524000000},
#   {'open': 2026.42,
#    'high': 2034.6,
#    'low': 1958.42,
#    'close': 1972.74,
#    'volume': 6219094,
#    'datetime': 1582610400000},
#   {'open': 1970.28,
#    'high': 2014.67,
#    'low': 1960.45,
#    'close': 1979.59,
#    'volume': 5240402,
#    'datetime': 1582696800000},
#   {'open': 1934.38,
#    'high': 1975.0,
#    'low': 1882.7621,
#    'close': 1884.3,
#    'volume': 8143993,
#    'datetime': 1582783200000},
#   {'open': 1814.63,
#    'high': 1889.76,
#    'low': 1811.129,
#    'close': 1883.75,
#    'volume': 9493797,
#    'datetime': 1582869600000},
#   {'open': 1906.49,
#    'high': 1954.51,
#    'low': 1870.0,
#    'close': 1953.95,
#    'volume': 6761651,
#    'datetime': 1583128800000},
#   {'open': 1975.37,
#    'high': 1996.33,
#    'low': 1888.0901,
#    'close': 1908.99,
#    'volume': 7534491,
#    'datetime': 1583215200000},
#   {'open': 1946.57,
#    'high': 1978.0,
#    'low': 1922.0,
#    'close': 1975.83,
#    'volume': 4772919,
#    'datetime': 1583301600000},
#   {'open': 1933.0,
#    'high': 1960.72,
#    'low': 1910.0,
#    'close': 1924.03,
#    'volume': 4748210,
#    'datetime': 1583388000000},
#   {'open': 1875.0,
#    'high': 1910.87,
#    'low': 1869.5,
#    'close': 1901.09,
#    'volume': 5273580,
#    'datetime': 1583474400000},
#   {'open': 1773.86,
#    'high': 1862.77,
#    'low': 1761.2901,
#    'close': 1800.61,
#    'volume': 7813232,
#    'datetime': 1583730000000},
#   {'open': 1870.88,
#    'high': 1894.27,
#    'low': 1818.17,
#    'close': 1891.82,
#    'volume': 7133310,
#    'datetime': 1583816400000},
#   {'open': 1857.85,
#    'high': 1871.3194,
#    'low': 1801.5,
#    'close': 1820.86,
#    'volume': 5646831,
#    'datetime': 1583902800000},
#   {'open': 1721.98,
#    'high': 1765.0,
#    'low': 1675.0,
#    'close': 1676.61,
#    'volume': 11346214,
#    'datetime': 1583989200000},
#   {'open': 1755.0,
#    'high': 1786.31,
#    'low': 1680.62,
#    'close': 1785.0,
#    'volume': 8809725,
#    'datetime': 1584075600000},
#   {'open': 1641.51,
#    'high': 1759.4519,
#    'low': 1626.0318,
#    'close': 1689.15,
#    'volume': 8917265,
#    'datetime': 1584334800000},
#   {'open': 1775.47,
#    'high': 1857.775,
#    'low': 1689.2402,
#    'close': 1807.84,
#    'volume': 10917129,
#    'datetime': 1584421200000},
#   {'open': 1750.0,
#    'high': 1841.66,
#    'low': 1745.0,
#    'close': 1830.0,
#    'volume': 9645218,
#    'datetime': 1584507600000},
#   {'open': 1860.0,
#    'high': 1945.0,
#    'low': 1832.65,
#    'close': 1880.93,
#    'volume': 10399943,
#    'datetime': 1584594000000},
#   {'open': 1926.31,
#    'high': 1957.0,
#    'low': 1820.73,
#    'close': 1846.09,
#    'volume': 9817850,
#    'datetime': 1584680400000},
#   {'open': 1827.75,
#    'high': 1919.4,
#    'low': 1812.0,
#    'close': 1902.83,
#    'volume': 7808489,
#    'datetime': 1584939600000},
#   {'open': 1951.495,
#    'high': 1955.0,
#    'low': 1900.3403,
#    'close': 1940.1,
#    'volume': 7147080,
#    'datetime': 1585026000000},
#   {'open': 1920.69,
#    'high': 1950.26,
#    'low': 1885.78,
#    'close': 1885.84,
#    'volume': 6479073,
#    'datetime': 1585112400000},
#   {'open': 1902.0,
#    'high': 1956.49,
#    'low': 1889.29,
#    'close': 1955.49,
#    'volume': 6235118,
#    'datetime': 1585198800000},
#   {'open': 1930.86,
#    'high': 1939.79,
#    'low': 1899.92,
#    'close': 1900.1,
#    'volume': 5387897,
#    'datetime': 1585285200000},
#   {'open': 1922.83,
#    'high': 1973.63,
#    'low': 1912.34,
#    'close': 1963.95,
#    'volume': 6126087,
#    'datetime': 1585544400000},
#   {'open': 1964.35,
#    'high': 1993.02,
#    'low': 1944.01,
#    'close': 1949.72,
#    'volume': 5123626,
#    'datetime': 1585630800000},
#   {'open': 1932.97,
#    'high': 1944.96,
#    'low': 1893.0,
#    'close': 1908.2,
#    'volume': 2156361,
#    'datetime': 1585713600000}],
#  'symbol': 'AMZN',
#  'empty': False}

# %% [markdown]
# # Below is an example of a quote:

# %%
# The QUOTE endpoint

# Define our endpoint
endpoint = r'https://api.tdameritrade.com/v1/marketdata/{}/quotes'.format('AAPL')

# Define our payload
payload = {'apikey':client_id}

# Make a request
content = requests.get(url = endpoint, params = payload)

data = content.json()
data
# Out:
# {'AAPL': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '037833100',
#   'symbol': 'AAPL',
#   'description': 'Apple Inc. - Common Stock',
#   'bidPrice': 242.8,
#   'bidSize': 500,
#   'bidId': 'K',
#   'askPrice': 243.0,
#   'askSize': 700,
#   'askId': 'K',
#   'lastPrice': 242.84,
#   'lastSize': 200,
#   'lastId': 'Q',
#   'openPrice': 246.5,
#   'highPrice': 248.72,
#   'lowPrice': 239.13,
#   'bidTick': ' ',
#   'closePrice': 254.29,
#   'netChange': -11.45,
#   'totalVolume': 44054638,
#   'quoteTimeInLong': 1585785597358,
#   'tradeTimeInLong': 1585785597340,
#   'mark': 242.8,
#   'exchange': 'q',
#   'exchangeName': 'NASD',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.0157,
#   'digits': 4,
#   '52WkHigh': 327.85,
#   '52WkLow': 170.27,
#   'nAV': 0.0,
#   'peRatio': 20.1247,
#   'divAmount': 3.08,
#   'divYield': 1.21,
#   'divDate': '2020-02-07 00:00:00.000',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 240.91,
#   'regularMarketLastSize': 27701,
#   'regularMarketNetChange': -13.38,
#   'regularMarketTradeTimeInLong': 1585771200793,
#   'netPercentChangeInDouble': -4.5027,
#   'markChangeInDouble': -11.49,
#   'markPercentChangeInDouble': -4.5185,
#   'regularMarketPercentChangeInDouble': -5.2617,
#   'delayed': True}}

# %%
# The QUOTES endpoint

# Define our endpoint
endpoint = r'https://api.tdameritrade.com/v1/marketdata/quotes'.format('AAPL')

# Define our payload
payload = {'apikey':client_id,
           'symbol':'GOOG,MSFT,AAPL,AMZN,PINS,EUR/USD'}

# Make a request
content = requests.get(url = endpoint, params = payload)

data = content.json()
data
# Out:
# {'GOOG': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '02079K107',
#   'symbol': 'GOOG',
#   'description': 'Alphabet Inc. - Class C Capital Stock',
#   'bidPrice': 1110.04,
#   'bidSize': 100,
#   'bidId': 'K',
#   'askPrice': 1113.0,
#   'askSize': 100,
#   'askId': 'Q',
#   'lastPrice': 1112.65,
#   'lastSize': 0,
#   'lastId': 'Q',
#   'openPrice': 1122.0,
#   'highPrice': 1129.6899,
#   'lowPrice': 1097.45,
#   'bidTick': ' ',
#   'closePrice': 1162.8101,
#   'netChange': -50.16,
#   'totalVolume': 2344173,
#   'quoteTimeInLong': 1585785544334,
#   'tradeTimeInLong': 1585785595016,
#   'mark': 1110.04,
#   'exchange': 'q',
#   'exchangeName': 'NASD',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.0552,
#   'digits': 4,
#   '52WkHigh': 1532.106,
#   '52WkLow': 1013.536,
#   'nAV': 0.0,
#   'peRatio': 23.13,
#   'divAmount': 0.0,
#   'divYield': 0.0,
#   'divDate': '',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 1105.62,
#   'regularMarketLastSize': 1836,
#   'regularMarketNetChange': -57.19,
#   'regularMarketTradeTimeInLong': 1585771200573,
#   'netPercentChangeInDouble': -4.3137,
#   'markChangeInDouble': -52.7701,
#   'markPercentChangeInDouble': -4.5381,
#   'regularMarketPercentChangeInDouble': -4.9183,
#   'delayed': True},
#  'MSFT': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '594918104',
#   'symbol': 'MSFT',
#   'description': 'Microsoft Corporation - Common Stock',
#   'bidPrice': 153.58,
#   'bidSize': 100,
#   'bidId': 'K',
#   'askPrice': 153.59,
#   'askSize': 100,
#   'askId': 'Q',
#   'lastPrice': 153.58,
#   'lastSize': 100,
#   'lastId': 'Q',
#   'openPrice': 153.0,
#   'highPrice': 157.75,
#   'lowPrice': 150.82,
#   'bidTick': ' ',
#   'closePrice': 157.71,
#   'netChange': -4.13,
#   'totalVolume': 57969926,
#   'quoteTimeInLong': 1585785599986,
#   'tradeTimeInLong': 1585785599986,
#   'mark': 153.58,
#   'exchange': 'q',
#   'exchangeName': 'NASD',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.0203,
#   'digits': 4,
#   '52WkHigh': 190.7,
#   '52WkLow': 118.1,
#   'nAV': 0.0,
#   'peRatio': 29.6403,
#   'divAmount': 2.04,
#   'divYield': 1.29,
#   'divDate': '2020-05-20 00:00:00.000',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 152.11,
#   'regularMarketLastSize': 49215,
#   'regularMarketNetChange': -5.6,
#   'regularMarketTradeTimeInLong': 1585771200469,
#   'netPercentChangeInDouble': -2.6187,
#   'markChangeInDouble': -4.13,
#   'markPercentChangeInDouble': -2.6187,
#   'regularMarketPercentChangeInDouble': -3.5508,
#   'delayed': True},
#  'AAPL': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '037833100',
#   'symbol': 'AAPL',
#   'description': 'Apple Inc. - Common Stock',
#   'bidPrice': 242.8,
#   'bidSize': 500,
#   'bidId': 'K',
#   'askPrice': 243.0,
#   'askSize': 700,
#   'askId': 'K',
#   'lastPrice': 242.84,
#   'lastSize': 200,
#   'lastId': 'Q',
#   'openPrice': 246.5,
#   'highPrice': 248.72,
#   'lowPrice': 239.13,
#   'bidTick': ' ',
#   'closePrice': 254.29,
#   'netChange': -11.45,
#   'totalVolume': 44054638,
#   'quoteTimeInLong': 1585785597358,
#   'tradeTimeInLong': 1585785597340,
#   'mark': 242.8,
#   'exchange': 'q',
#   'exchangeName': 'NASD',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.0157,
#   'digits': 4,
#   '52WkHigh': 327.85,
#   '52WkLow': 170.27,
#   'nAV': 0.0,
#   'peRatio': 20.1247,
#   'divAmount': 3.08,
#   'divYield': 1.21,
#   'divDate': '2020-02-07 00:00:00.000',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 240.91,
#   'regularMarketLastSize': 27701,
#   'regularMarketNetChange': -13.38,
#   'regularMarketTradeTimeInLong': 1585771200793,
#   'netPercentChangeInDouble': -4.5027,
#   'markChangeInDouble': -11.49,
#   'markPercentChangeInDouble': -4.5185,
#   'regularMarketPercentChangeInDouble': -5.2617,
#   'delayed': True},
#  'AMZN': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '023135106',
#   'symbol': 'AMZN',
#   'description': 'Amazon.com, Inc. - Common Stock',
#   'bidPrice': 1910.5,
#   'bidSize': 100,
#   'bidId': 'K',
#   'askPrice': 1912.0,
#   'askSize': 200,
#   'askId': 'K',
#   'lastPrice': 1912.0,
#   'lastSize': 0,
#   'lastId': 'Q',
#   'openPrice': 1932.97,
#   'highPrice': 1944.96,
#   'lowPrice': 1893.0,
#   'bidTick': ' ',
#   'closePrice': 1949.72,
#   'netChange': -37.72,
#   'totalVolume': 4121875,
#   'quoteTimeInLong': 1585785578026,
#   'tradeTimeInLong': 1585785581549,
#   'mark': 1910.5,
#   'exchange': 'q',
#   'exchangeName': 'NASD',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.0343,
#   'digits': 4,
#   '52WkHigh': 2185.95,
#   '52WkLow': 1626.032,
#   'nAV': 0.0,
#   'peRatio': 83.71,
#   'divAmount': 0.0,
#   'divYield': 0.0,
#   'divDate': '',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 1907.7,
#   'regularMarketLastSize': 2519,
#   'regularMarketNetChange': -42.02,
#   'regularMarketTradeTimeInLong': 1585771200802,
#   'netPercentChangeInDouble': -1.9346,
#   'markChangeInDouble': -39.22,
#   'markPercentChangeInDouble': -2.0116,
#   'regularMarketPercentChangeInDouble': -2.1552,
#   'delayed': True},
#  'PINS': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '72352L106',
#   'symbol': 'PINS',
#   'description': 'Pinterest, Inc. Class A Common Stock',
#   'bidPrice': 14.17,
#   'bidSize': 300,
#   'bidId': 'P',
#   'askPrice': 14.85,
#   'askSize': 1600,
#   'askId': 'P',
#   'lastPrice': 14.17,
#   'lastSize': 200,
#   'lastId': 'N',
#   'openPrice': 14.6,
#   'highPrice': 14.69,
#   'lowPrice': 13.87,
#   'bidTick': ' ',
#   'closePrice': 15.44,
#   'netChange': -1.27,
#   'totalVolume': 9082519,
#   'quoteTimeInLong': 1585785600038,
#   'tradeTimeInLong': 1585783754837,
#   'mark': 14.17,
#   'exchange': 'n',
#   'exchangeName': 'NYSE',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.0488,
#   'digits': 2,
#   '52WkHigh': 36.83,
#   '52WkLow': 10.1,
#   'nAV': 0.0,
#   'peRatio': 0.0,
#   'divAmount': 0.0,
#   'divYield': 0.0,
#   'divDate': '',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 14.17,
#   'regularMarketLastSize': 1484,
#   'regularMarketNetChange': -1.27,
#   'regularMarketTradeTimeInLong': 1585780200004,
#   'netPercentChangeInDouble': -8.2254,
#   'markChangeInDouble': -1.27,
#   'markPercentChangeInDouble': -8.2254,
#   'regularMarketPercentChangeInDouble': -8.2254,
#   'delayed': True},
#  'EUR/USD': {'assetType': 'FOREX',
#   'assetMainType': 'FOREX',
#   'symbol': 'EUR/USD',
#   'bidPriceInDouble': 1.09428,
#   'askPriceInDouble': 1.09444,
#   'lastPriceInDouble': 1.09436,
#   'bidSizeInLong': 1000000,
#   'askSizeInLong': 1000000,
#   'totalVolume': 51280000,
#   'lastSizeInLong': 100000,
#   'quoteTimeInLong': 1585794407020,
#   'tradeTimeInLong': 1585794407020,
#   'highPriceInDouble': 1.09675,
#   'lowPriceInDouble': 1.09372,
#   'closePriceInDouble': 1.10305,
#   'exchange': 'T',
#   'description': 'Euro/USDollar Spot',
#   'openPriceInDouble': 1.09634,
#   'changeInDouble': -0.00869,
#   'percentChange': 0,
#   'exchangeName': 'GFT',
#   'digits': 2,
#   'securityStatus': 'Unknown',
#   'tick': 0.0,
#   'tickAmount': 0.0,
#   'product': '',
#   'tradingHours': '',
#   'isTradable': False,
#   'marketMaker': '',
#   '52WkHighInDouble': 1.09675,
#   '52WkLowInDouble': 1.09372,
#   'mark': 1.09436,
#   'delayed': False}}
